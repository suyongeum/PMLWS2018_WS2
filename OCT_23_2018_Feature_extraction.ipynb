# %% [markdown]
# # Feature extraction using panda

# %%
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from sklearn import metrics
import matplotlib.pyplot as plt
from string import punctuation
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score

# %%
from google.colab import drive
drive.mount('/gdrive/')
# Out:
# Mounted at /gdrive/

# %%
# !ls "/gdrive/My Drive/Colab Notebooks/"
path = "/gdrive/My Drive/Colab Notebooks/"
# Out:
# data.csv	OCT_23_2018_Feature_extraction.ipynb  OCT_23_2018_SVM.ipynb
# mnist_data.csv	OCT_23_2018_PCA.ipynb

# %%
traindata=pd.read_csv(path+'/data.csv',encoding="shift-jis",header=None, names=('difficulty', 'word'),keep_default_na=False)
print(len(traindata))
print(traindata.head())
# Out:
# 11998
#    difficulty     word
# 0           3  dismiss
# 1           3  liberty
# 2           3    sadly
# 3           3  absence
# 4           3  display

# %% [markdown]
# # Feature adding

# %%
wordLength = []

for i in range(len(traindata)):
    wordLength.append(len(traindata.word[i]))
    
traindata["length"]=wordLength
print(traindata.head())
# Out:
#    difficulty     word  length
# 0           3  dismiss       7
# 1           3  liberty       7
# 2           3    sadly       5
# 3           3  absence       7
# 4           3  display       7
